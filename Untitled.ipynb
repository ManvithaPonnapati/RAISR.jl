# %%
using Images,Distributions, JLD

test_image = "/Users/manvithaponnapati/RAISR/test_data/test_image_1.jpg"
test_im = load(test_image)

# %%
rgb1= channelview(YCbCr.(test_im))

# %%
convert(Array{RGB}, (YCbCr.(test_im)))
# Out:
# 160×240 Array{RGB{Float32},2}:
#  RGB{Float32}(0.0745206,0.0627559,0.0274618)  …  RGB{Float32}(0.0470662,0.0431446,0.0235368)
#  RGB{Float32}(0.0745206,0.0627559,0.0274618)     RGB{Float32}(0.0470662,0.0431446,0.0235368)
#  RGB{Float32}(0.0745206,0.0627559,0.0274618)     RGB{Float32}(0.0549107,0.0509891,0.0313813)
#  RGB{Float32}(0.0666778,0.0666778,0.0274621)     RGB{Float32}(0.0588329,0.0549114,0.0353035)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)     RGB{Float32}(0.0627552,0.0588336,0.0392258)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)  …  RGB{Float32}(0.0666774,0.0627558,0.043148)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)     RGB{Float32}(0.0705997,0.0666781,0.0470703)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)     RGB{Float32}(0.0705997,0.0666781,0.0470703)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)     RGB{Float32}(0.0666774,0.0627558,0.043148)
#  RGB{Float32}(0.0666779,0.0666779,0.0353053)     RGB{Float32}(0.0666779,0.0666779,0.0353053)
# ...
